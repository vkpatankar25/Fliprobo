# %% [markdown]
# # 7. Write a program to scrap all the available details of top 10 gaming laptops from digit.in.

# %%
#lets import all required libraries
import selenium
import pandas as pd
from selenium import webdriver

# %%
#lets first connect to the web driver
driver=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver.get('https://www.digit.in/')

# %%
url='https://www.digit.in/search/?keyword=gaming%20laptops'

# %%
#lets open the webpage through web driver
driver.get(url)

# %%
titles=[]

# %%
#lets extract all the tags
titles=driver.find_elements_by_xpath("//div[@class='searchProduct-desc']")
titles[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e2971d2e0384ff0e958e7ccf5b704829", element="3ac6f3ca-c3bc-464f-8c90-41b507f1c02c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e2971d2e0384ff0e958e7ccf5b704829", element="16327ce8-526a-4487-a451-299dbf7e41f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e2971d2e0384ff0e958e7ccf5b704829", element="2ac7dce9-9d6e-4031-b08e-191caea08e30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e2971d2e0384ff0e958e7ccf5b704829", element="fb8d156a-db30-4208-b356-a7801bb6c0bb")>]

# %%
for i in titles:
    title=i.text
    job_titles.append(title)
job_titles[0:10]
# Out:
# ['HP Envy 15-k006tx',
#  'Asus G750JX-CV069P',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'Lenovo IdeaPad Y570',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'ASUS ROG Cetra',
#  'Truvison TX3271',
#  'Lenovo G50-30',
#  'Budget gaming laptops',
#  'Backpacks for gaming laptops']

# %% [markdown]
# # 6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
#lets first connect to the web driver
driver1=webdriver.Chrome(r"C://chromedriver.exe")
driver1.get('https://trak.in/')

url='https://trak.in/india-startup-funding-investment-2015/'

#lets open the webpage through web driver
driver1.get(url)

# %%
fi_date=[]
startup=[]
industry=[]
vertical=[]
location=[]
name=[]
invetment_type=[]
amount=[]

# %%
#lets extract all the tags
date=driver1.find_elements_by_xpath("//td[@class='column-2']")
date[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="1ec9fe7f-f217-4a81-9c99-e7fa22c098c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="ff32309f-52fe-4a19-843e-7f7a89b6071b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="622226b9-b690-4328-bc1e-34481e9798b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="3336ff1c-d660-4b35-90eb-d45e002c1a19")>]

# %%
for i in date:
    title=i.text
    fi_date.append(title)
fi_date[0:4]
# Out:
# ['11/02/2021', '22/02/2021', '19/02/2021', '17/02/2021']

# %%
start=driver1.find_elements_by_xpath("//td[@class='column-3']")
start[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="dc35372b-726f-48d9-950a-c1451586b373")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="dccb6a24-0363-4919-8d5b-9026649e545d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="78282043-5ae7-4eb6-b417-7e711af7c3cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a500d4fbca5c31f041f98571b5434abe", element="5a576b3d-63f6-43f5-9cc1-8d7b3e2b065c")>]

# %%
for i in start:
    title1=i.text
    startup.append(title1)
startup[0:4]
# Out:
# ['Doubtnut', 'Zomato', 'Fingerlix', 'Zolve']

# %%
indus=driver1.find_elements_by_xpath("//td[@class='column-4']")
for i in indus:
    title2=i.text
    industry.append(title2)
industry[0:4]
# Out:
# ['Edu Tech', 'Hospitality', 'Hospitality', 'FinTech']

# %%
verti=driver1.find_elements_by_xpath("//td[@class='column-5']")
for i in verti:
    title3=i.text
    vertical.append(title3)
vertical[0:4]
# Out:
# ['E-Learning Platform',
#  'Online Food Delivery Platform',
#  'Semi-cooked food delivery app',
#  'Global Neobank Venture']

# %%
loca=driver1.find_elements_by_xpath("//td[@class='column-6']")
for i in loca:
    title4=i.text
    location.append(title4)
location[0:4]
# Out:
# ['Gurgaon', 'Gurgaon', 'Mumbai', 'Mumbai']

# %%
nam=driver1.find_elements_by_xpath("//td[@class='column-7']")
for i in nam:
    title5=i.text
    name.append(title5)
name[0:4]
# Out:
# ['SIG Global, Sequoia Capital, WaterBridge Ventures and ON Mauritius',
#  'Tiger Global, Kora',
#  'Rhodium Trust, Accel Partners and Swiggy',
#  'Accel Partners and Lightspeed Venture Partners']

# %%
amt=driver1.find_elements_by_xpath("//td[@class='column-9']")
for i in amt:
    title7=i.text
    amount.append(title7)
amount[0:4]
# Out:
# ['2,500,000', '250,000,000', '2,747,045.20', '1,50,00,000']

# %%
trak=pd.DataFrame({})
trak['dates']=fi_date[45:70]
trak['startups']=startup[45:70]
trak['company']=industry[45:70]
trak['verticals']=vertical[45:70]
trak['locations']=location[45:70]
trak['names']=name[45:70]
trak['amounts']=amount[45:70]

# %%
trak
# Out:
#          dates      startups                                 company  \
# 0   09/09/2020        Qshala                                 EduTech
# 1   02/09/2020         Winzo                           Online Gaming
# 2   09/09/2020   Hippo Video  Video Customer Experience(CX) Platform
# 3   07/09/2020       Melorra                              E-commerce
# 4   07/09/2020           1mg                              E-commerce
# 5   31/08/2020         mfine                              HealthTech
# 6   31/08/2020          Apna                         Human Resources
# 7   03/09/2020       Railofy                          Transportation
# 8   15/08/2020        Practo                              HealthTech
# 9   13/08/2020       Medlife                              E-commerce
# 10  13/08/2020     HungerBox                                FoodTech
# 11  04/08/2020         Dunzo                   Hyper-local Logistics
# 12  11/08/2020      Terra.do                                 EduTech
# ...

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
#lets first connect to the web driver
driver4=webdriver.Chrome(r"C://chromedriver.exe")
driver4.get('https://en.wikipedia.org/')

url='https://en.wikipedia.org/wiki/List_of_extreme_points_of_India'

#lets open the webpage through web driver
driver4.get(url)

# %%
city=[]
latlong=[]

# %%
name=driver4.find_elements_by_xpath("//td[@class='fn org']")
for i in name:
    title2=i.text
    city.append(title2)
city[0:4]
# Out:
# ['East of Indira Col at Siachen Glacier',
#  'East of Kilik Pass in the Karakoram Mountains on Xinjiang-Gilgit-Baltistan border',
#  'Indira Point on the southernmost end of Great Nicobar Island of the Nicobar Islands',
#  'Cape Comorin near Kanyakumari']

# %%
cord=driver4.find_elements_by_xpath("//span[@class='geo-dec']")
for i in cord:
    title3=i.text
    latlong.append(title3)
latlong[0:4]
# Out:
# ['35.674521°N 76.844485°E',
#  '37.08586°N 74.70291°E',
#  '33.25615°N 76.79877°E',
#  '6.74678°N 93.84260°E']

# %%
cordinate=pd.DataFrame({})
cordinate['name']=city[0:10]
cordinate['lat_long']=latlong[0:10]

# %%
cordinate
# Out:
#                                                 name                 lat_long
# 0              East of Indira Col at Siachen Glacier  35.674521°N 76.844485°E
# 1  East of Kilik Pass in the Karakoram Mountains ...    37.08586°N 74.70291°E
# 2  Indira Point on the southernmost end of Great ...    33.25615°N 76.79877°E
# 3                      Cape Comorin near Kanyakumari     6.74678°N 93.84260°E
# 4  Southeast of Dong (before Kibithu in Anjaw dis...     8.06890°N 77.55230°E
# 5  Chaukan Pass, east of Vijaynagar in Changlang ...    28.01168°N 97.39564°E
# 6                        Sir Creek in Kutch district    27.13611°N 97.16575°E
# 7                                      Kangchenjunga      23.6261°N 68.1941°E
# 8                                                 K2    27.70250°N 88.14833°E
# 9                                         Nanda Devi    35.88250°N 76.51333°E

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com

# %%
#lets first connect to the web driver
driver2=webdriver.Chrome(r"C://chromedriver.exe")
driver2.get('https://www.flipkart.com/')

url='https://www.flipkart.com/search?q=oneplus%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

#lets open the webpage through web driver
driver2.get(url)

# %%
rating=[]
price=[]
mobile=[]
desc=[]

# %%
d=driver2.find_elements_by_xpath("//li[@class='rgWa7D']")
for i in d:
    title2=i.text
    desc.append(title2)
desc[0:4]
# Out:
# ['Netflix|Prime Video|Disney+Hotstar|Youtube',
#  'Operating System: Android',
#  'Full HD 1920 x 1080 Pixels',
#  '20 W Speaker Output']

# %%
brand=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['OnePlus Y Series 108 cm (43 inch) Full HD LED Smart Android TV',
#  'OnePlus Y Series 80 cm (32 inch) HD Ready LED Smart Android TV',
#  'OnePlus U Series 138.8 cm (55 inch) Ultra HD (4K) LED Smart Android TV',
#  'OnePlus Q1 Series 138.8 cm (55 inch) QLED Ultra HD (4K) Smart Android TV']

# %%
rev=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
# Out:
# ['4.316,043 Ratings & 1,427 Reviews',
#  '4.316,043 Ratings & 1,427 Reviews',
#  '4.394 Ratings & 8 Reviews',
#  '4.5897 Ratings & 129 Reviews']

# %%
cost=driver2.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']")
for i in cost:
    title4=i.text
    price.append(title4)
price[0:4]
# Out:
# ['₹25,999', '₹15,499', '₹52,999', '₹62,899']

# %%
phone=pd.DataFrame({})
phone['mobiles']=mobile[0:40]
phone['review&rating']=rating[0:40]
phone['prices']=price[0:40]
phone['description']=desc[0:40]

# %%
phone
# Out:
#                                               mobiles  \
# 0   OnePlus Y Series 108 cm (43 inch) Full HD LED ...
# 1   OnePlus Y Series 80 cm (32 inch) HD Ready LED ...
# 2   OnePlus U Series 138.8 cm (55 inch) Ultra HD (...
# 3   OnePlus Q1 Series 138.8 cm (55 inch) QLED Ultr...
# 4        OnePlus Bullets Wireless Z Bluetooth Headset
# 5   OnePlus Bullets Wireless Z Bass Edition Blueto...
# 6   OnePlus Bullets Wireless Z Bass Edition Blueto...
# 7        OnePlus Bullets Wireless Z Bluetooth Headset
# 8                    OnePlus Buds Z Bluetooth Headset
# 9                    OnePlus Buds Z Bluetooth Headset
# 10  OnePlus 10000 mAh Power Bank (18 W, Fast Charg...
# 11  OnePlus 10000 mAh Power Bank (18 W, Fast Charg...
# 12                                       OnePlus Band
# 13  jkg DASH CHARGING CABLE 6 A 1 m ORIGINAL USB T...
# 14                   OnePlus Buds Z Bluetooth Headset
# 15                     OnePlus Buds Bluetooth Headset
# ...

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com

# %%
#lets first connect to the web driver
driver5=webdriver.Chrome(r"C://chromedriver.exe")
driver5.get('https://images.google.com/')

url='https://www.google.com/search?q=cars&tbm=isch&sxsrf=ALeKk02rRqSeBmHtl9YdDXWcFR_8kMV0HA%3A1618469291320&source=hp&biw=1366&bih=625&ei=q-F3YPWtEdKO4-EPxM-WsAw&oq=cars&gs_lcp=CgNpbWcQAzIECCMQJzIFCAAQsQMyBQgAELEDMgIIADIFCAAQsQMyBQgAELEDMgUIABCxAzIFCAAQsQMyAggAMgIIADoHCCMQ6gIQJzoICAAQsQMQgwFQn2NYwndg_XhoAnAAeACAAXiIAZsEkgEDMC41mAEAoAEBqgELZ3dzLXdpei1pbWewAQo&sclient=img&ved=0ahUKEwi1r7_50__vAhVSxzgGHcSnBcYQ4dUDCAc&uact=5'
url1='https://www.google.com/search?q=fruit&tbm=isch&sxsrf=ALeKk03RTTMZZJrtTuTwGb3_RveeRIEKVQ%3A1618469862702&source=hp&biw=1366&bih=625&ei=5uN3YJTLKMPF4-EPpJSEoAI&oq=fruit&gs_lcp=CgNpbWcQAzIICAAQsQMQgwEyBQgAELEDMggIABCxAxCDATIFCAAQsQMyBQgAELEDMgUIABCxAzIFCAAQsQMyBQgAELEDMgUIABCxAzIFCAAQsQM6BAgjECc6AggAUM8VWN4nYNYpaAFwAHgAgAG-AYgBvwaSAQMwLjaYAQCgAQGqAQtnd3Mtd2l6LWltZw&sclient=img&ved=0ahUKEwiU1vmJ1v_vAhXD4jgGHSQKASQQ4dUDCAc&uact=5'
url2='https://www.google.com/search?q=machine+learning&tbm=isch&sxsrf=ALeKk028NTeyQkhMh9d5jvjmbeVzyZeqpg%3A1618469881695&source=hp&biw=1366&bih=625&ei=-eN3YJmMKN6R4-EP5Juu0Ak&oq=machine&gs_lcp=CgNpbWcQARgAMgUIABCxAzIFCAAQsQMyBQgAELEDMgUIABCxAzIICAAQsQMQgwEyBQgAELEDMgIIADIFCAAQsQMyAggAMgUIABCxAzoECCMQJ1CtBlivE2DfIGgAcAB4AIABlwGIAe0GkgEDMC43mAEAoAEBqgELZ3dzLXdpei1pbWc&sclient=img'

#lets open the webpage through web driver
driver5.get(url+url1+url2)

# %%
img_car=[]

for i in range(0,10):
    for j in driver5.find_elements_by_xpath("//div[@class='bRMDJf islir']/img"):
        img_car.append(j.get_attribute("src"))

# %%
img_fruit=[]

for i in range(0,10):
    for j in driver5.find_elements_by_xpath("//div[@class='bRMDJf islir']/img"):
        img_fruit.append(j.get_attribute("src"))

# %%
img_ml=[]

for i in range(0,10):
    for j in driver5.find_elements_by_xpath("//div[@class='bRMDJf islir']/img"):
        img_ml.append(j.get_attribute("src"))

# %%
print(len(img_car),len(img_fruit),len(img_ml))
# Out:
# 980 490 490

# %%
img=pd.DataFrame({})
img['cars']=img_car[0:100]
img['fruits']=img_fruit[0:100]
img['machine_learning']=img_ml[0:100]

# %%
img
# Out:
#                                                  cars  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98  ......
# 99  ......
#
#                                                fruits  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98  ......
# 99  ......
#
#                                      machine_learning
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95                                               None
# ...

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in.

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a dataframe and csv.

# %%
#lets first connect to the web driver
driver6=webdriver.Chrome(r"C://chromedriver.exe")
driver6.get('https://www.amazon.in/')
search=input('driver6.find_element_by_id:' )
input('search.send_keys:' )
# Out:
# driver6.find_element_by_id:twotabsearchtextbox
# search.send_keys:mobiles
# 'mobiles'

# %%
url='https://www.amazon.in/s?k=mobiles&ref=nb_sb_noss_2'
url1='https://www.amazon.in/s?k=mobiles&page=2&qid=1618478558&ref=sr_pg_2'
url3='https://www.amazon.in/s?k=mobiles&page=3&qid=1618478629&ref=sr_pg_3'

driver6.get(url+url1+url2)

# %%
name=[]
price=[]
rating=[]

# %%
brand=driver6.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in brand:
    title2=i.text
    name.append(title2)
name[0:4] 
brand1=driver6.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in brand1:
    title21=i.text
    name.append(title21)
name[0:4] 
brand2=driver6.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in brand2:
    title22=i.text
    name.append(title22)
name[0:4]
# Out:
# ['Samsung Galaxy M31 (Space Black, 6GB RAM, 128GB Storage)',
#  'Panasonic Eluga i7 (2GB RAM, 16GB Storage, Finger Print Sensor, 4000mAh Battery) (Black)',
#  'Samsung Galaxy M21 (Raven Black, 4GB RAM, 64GB Storage)',
#  'Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor']

# %%
cost=driver6.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in cost:
    title4=i.text
    price.append(title4)
price[0:4]
cost1=driver6.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in cost1:
    title41=i.text
    price.append(title41)
price[0:4]
cost2=driver6.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in cost2:
    title42=i.text
    price.append(title42)
price[0:4]
# Out:
# ['16,499', '5,004', '12,499', '6,799']

# %%
rev=driver6.find_elements_by_xpath("//span[@class='a-size-base']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver6.find_elements_by_xpath("//span[@class='a-size-base']")
for i in rev1:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev2=driver6.find_elements_by_xpath("//span[@class='a-size-base']")
for i in rev2:
    title32=i.text
    rating.append(title32)
rating[0:4]
# Out:
# ['166,082', '2,563', '117,731', '32,361']

# %%
mobile=pd.DataFrame({})
mobile['titles']=name[0:48]
mobile['ratings']=rating[0:48]
mobile['prices']=price[0:48]

# %%
mobile
# Out:
#                                                titles  ratings  prices
# 0   Samsung Galaxy M31 (Space Black, 6GB RAM, 128G...  166,082  16,499
# 1   Panasonic Eluga i7 (2GB RAM, 16GB Storage, Fin...    2,563   5,004
# 2   Samsung Galaxy M21 (Raven Black, 4GB RAM, 64GB...  117,731  12,499
# 3   Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage) | 2...   32,361   6,799
# 4   Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage...    4,139  10,999
# 5   Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...   32,361   7,499
# 6   Redmi Note 9 (Arctic White, 4GB RAM, 64GB Stor...   47,105  10,999
# 7       Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage)   27,705   8,799
# 8   Redmi Note 9 (Aqua Green, 4GB RAM, 64GB Storag...   47,105  10,999
# 9   Redmi 9A (Midnight Black, 2GB RAM, 32GB Storag...   32,361   6,799
# 10  Samsung Galaxy M12 (White,4GB RAM, 64GB Storag...    4,139  10,999
# 11  Samsung Galaxy M12 (Black,6GB RAM, 128GB Stora...    4,139  13,499
# ...
