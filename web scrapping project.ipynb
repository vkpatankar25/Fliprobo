# %% [markdown]
# # 1. Python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
wiki=requests.get('https://en.wikipedia.org/wiki/Main_Page')
wiki
# Out:
# <Response [200]>

# %%
wiki.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"44a7c760-24d9-413e-93ac-bea454f376fb","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRel
# ...

# %%
soup=BeautifulSoup(wiki.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
#lets extract all the tags 
header=soup.find_all('span',class_='mw-headline')
header[0:4]
# Out:
# [<span class="mw-headline" id="From_today's_featured_article">From today's featured article</span>,
#  <span class="mw-headline" id="Did_you_know_...">Did you know ...</span>,
#  <span class="mw-headline" id="In_the_news">In the news</span>,
#  <span class="mw-headline" id="On_this_day">On this day</span>]

# %%
header_all=[]
for i in header:
    header_all.append(i.text)
header_all
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %% [markdown]
# # 2. Python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release)

# %%
import pandas as pd
import numpy as np

import requests
from requests import get
from bs4 import BeautifulSoup

from time import sleep
from random import randint

# %%
# Creating the lists we want to write into
titles = []
years = []
imdb_ratings = []

# %%
headers = {'Accept-Language': 'en-US, en;q=0.5'}

# %%
pages = np.arange(1, 101, 50)
pages
# Out:
# array([ 1, 51])

# %%
# Storing each of the urls  
for page in pages:
    # Getting the contents from the each url
    page = requests.get('https://www.imdb.com/search/title/?groups=top_1000&start=' + str(page) + '&ref_=adv_nxt', headers=headers)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    # Aiming the part of the html we want to get the information from
    movie_div = soup.find_all('div', class_='lister-item mode-advanced')
    
    sleep(randint(2,10))
    
    for container in movie_div:
        # Scraping the movie's name
        name = container.h3.a.text
        titles.append(name)
        
        # Scraping the movie's year
        year = container.h3.find('span', class_='lister-item-year').text
        years.append(year)
        
        # Scraping the rating
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)

# %%
movies = pd.DataFrame({'movie':titles,
                       'year':years,
                       'imdb_rating':imdb_ratings})

movies
# Out:
#                            movie    year  imdb_rating
# 0   Zack Snyder's Justice League  (2021)          8.5
# 1    Judas and the Black Messiah  (2021)          7.7
# 2              Avengers: Endgame  (2019)          8.4
# 3                           Soul  (2020)          8.1
# 4     The Trial of the Chicago 7  (2020)          7.8
# ..                           ...     ...          ...
# 95        Léon: The Professional  (1994)          8.5
# 96                         Logan  (2017)          8.1
# 97           Saving Private Ryan  (1998)          8.6
# 98                    Braveheart  (1995)          8.3
# 99  Rogue One: A Star Wars Story  (2016)          7.8
#
# [100 rows x 3 columns]

# %% [markdown]
# # 3. Python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com’

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://bookpage.com/reviews?book_genre=fiction&page=1')
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>Fiction Book Reviews | BookPage</title>\n<meta name="description" content="Fiction book recommendations of the best new books and more.">\n<meta name="keywords" content="book reviews, books and literature, writing and writers">\n<link rel="canonical" href="https://bookpage.com/reviews?book_genre=fiction&amp;page=1">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Fiction Book Reviews">\n<meta property="og:description" content="Fiction book recommendations of the best new books and more.">\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://bookpage.com/reviews?book_genre=fiction&amp;page=1">\n<meta property="og:image" content="//www.bookpage.com/default_image.jpg">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" content="@bookpage">\n
# ...

# %%
soup=BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Fiction Book Reviews | BookPage</title>
# <meta content="Fiction book recommendations of the best new books and more." name="description"/>
# <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/reviews?book_genre=fiction&amp;page=1" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Fiction Book Reviews" property="og:title"/>
# <meta content="Fiction book recommendations of the best new books and more." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/reviews?book_genre=fiction&amp;page=1" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# ...

# %%
#lets extract all the tags 
name=soup.find_all('div',class_='flex-article-content')
name[0:4]
# Out:
# [<div class="flex-article-content">
#  <h4 class="italic">
#  <a href="/reviews/26072-jamie-figueroa-brother-sister-mother-explorer-fiction">Brother, Sister, Mother, Explorer </a>
#  </h4>
#  <p class="sans bold">
#  Jamie Figueroa
#  </p>
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=literary_fiction">Literary Fiction</a>
#  </p>
#  <p class="excerpt">
#  Ghosts hover over Jamie Figueroa’s debut, a lyrical contemplation of how we can never run away from our past.
#  </p>
#  <div class="read-full">
#  <a href="/reviews/26072-jamie-figueroa-brother-sister-mother-explorer-fiction">Read the Review <i class="zmdi zmdi-chevron-right"></i></a>
#  </div>
#  </div>,
#  <div class="flex-article-content">
#  <h4 class="italic">
#  <a href="/reviews/25985-pamela-terry-sweet-taste-muscadines-fiction">The Sweet Taste of Muscadines</a>
#  </h4>
#  <p class="sans bold">
#  Pamela Terry
#  </p>
# ...

# %%
book_name=[]
for i in name:
     book_name.append(i.get_text().replace('\n',''))
book_name[0:5]
# Out:
# ['Brother, Sister, Mother, Explorer Jamie FigueroaFiction / Literary FictionGhosts hover over Jamie Figueroa’s debut, a lyrical contemplation of how we can never run away from our past.Read the Review ',
#  'The Sweet Taste of MuscadinesPamela TerryFiction / Family DramaPamela Terry’s debut novel sometimes feels like a mashup of Fried Green Tomatoes and You Can’t Go Home Again with a sprinkling of William Faulkner.Read the Review ',
#  ' ★ We Begin at the EndChris WhitakerFiction / Crime FictionChris Whitaker combines a brisk pace, a solid California voice and perhaps a record-setting cuss count.Read the Review ',
#  'Creatures of PassageMorowa YejidéFiction / Speculative FictionThis contemporary fairy tale’s grandeur and psychedelic wonderment undergird a serious warning, urging readers to find a way toward a saner future.Read the Review ',
# ...

# %%
author=soup.find_all('p',class_='sans bold')
author[0:4]
# Out:
# [<p class="sans bold">
#  Jamie Figueroa
#  </p>,
#  <p class="sans bold">
#  Pamela Terry
#  </p>,
#  <p class="sans bold">
#  Chris Whitaker
#  </p>,
#  <p class="sans bold">
#  Morowa Yejidé
#  </p>]

# %%
book_author=[]
for i in author:
     book_author.append(i.get_text().replace('\n',''))
book_author[0:5]
# Out:
# ['Jamie Figueroa',
#  'Pamela Terry',
#  'Chris Whitaker',
#  'Morowa Yejidé',
#  'Laura Maylene Walter']

# %%
genre=soup.find_all('p',class_='genre-links hidden-phone')
genre[0:4]
# Out:
# [<p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=literary_fiction">Literary Fiction</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=family_drama">Family Drama</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=crime_fiction">Crime Fiction</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=speculative_fiction">Speculative Fiction</a>
#  </p>]

# %%
book_genre=[]
for i in genre:
     book_genre.append(i.get_text().replace('\n',''))
book_genre[0:5]
# Out:
# ['Fiction / Literary Fiction',
#  'Fiction / Family Drama',
#  'Fiction / Crime Fiction',
#  'Fiction / Speculative Fiction',
#  'Fiction / Dystopian Fiction']

# %%
review=soup.find_all('p',class_='excerpt')
review[0:4]
# Out:
# [<p class="excerpt">
#  Ghosts hover over Jamie Figueroa’s debut, a lyrical contemplation of how we can never run away from our past.
#  </p>,
#  <p class="excerpt">
#  Pamela Terry’s debut novel sometimes feels like a mashup of <i>Fried Green Tomatoes</i> and <i>You Can’t Go Home Again</i> with a sprinkling of William Faulkner.
#  </p>,
#  <p class="excerpt">
#  Chris Whitaker combines a brisk pace, a solid California voice and perhaps a record-setting cuss count.
#  </p>,
#  <p class="excerpt">
#  This contemporary fairy tale’s grandeur and psychedelic wonderment undergird a serious warning, urging readers to find a way toward a saner future.
#  </p>]

# %%
book_review=[]
for i in review:
     book_review.append(i.get_text().replace('\n',''))
book_review[0:5]
# Out:
# ['Ghosts hover over Jamie Figueroa’s debut, a lyrical contemplation of how we can never run away from our past.',
#  'Pamela Terry’s debut novel sometimes feels like a mashup of Fried Green Tomatoes and You Can’t Go Home Again with a sprinkling of William Faulkner.',
#  'Chris Whitaker combines a brisk pace, a solid California voice and perhaps a record-setting cuss count.',
#  'This contemporary fairy tale’s grandeur and psychedelic wonderment undergird a serious warning, urging readers to find a way toward a saner future.',
#  'In the circumscribed dystopia of Laura Maylene Walter’s debut novel, Body of Stars, markings on girls’ bodies tell their futures, but one young woman learns to navigate in a new way—by using herself as constellation.']

# %%
import pandas as pd
page=pd.DataFrame({})
page['name']=book_name[:5]
page['author']=book_author[:5]
page['genre']=book_genre[:5]
page['review']=book_review[:5]

# %%
page
# Out:
#                                                 name                author  \
# 0  Brother, Sister, Mother, Explorer Jamie Figuer...        Jamie Figueroa
# 1  The Sweet Taste of MuscadinesPamela TerryFicti...          Pamela Terry
# 2   ★ We Begin at the EndChris WhitakerFiction / ...        Chris Whitaker
# 3  Creatures of PassageMorowa YejidéFiction / Spe...         Morowa Yejidé
# 4  Body of StarsLaura Maylene WalterFiction / Dys...  Laura Maylene Walter
#
#                            genre  \
# 0     Fiction / Literary Fiction
# 1         Fiction / Family Drama
# 2        Fiction / Crime Fiction
# 3  Fiction / Speculative Fiction
# 4    Fiction / Dystopian Fiction
#
#                                               review
# 0  Ghosts hover over Jamie Figueroa’s debut, a ly...
# 1  Pamela Terry’s debut novel sometimes feels lik...
# 2  Chris Whitaker combines a brisk pace, a solid ...
# 3  This contemporary fairy tale’s grandeur and ps...
# ...

# %% [markdown]
# # 4. Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
cricket=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
cricket
# Out:
# <Response [200]>

# %%
cricket.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta proper
# ...

# %%
soup1=BeautifulSoup(cricket.content,'html.parser')
soup1
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
#lets extract all the tags 
odi=soup1.find_all('span',class_='u-hide-phablet')
odi[0:10]
# Out:
# [<span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Afghanistan</span>]

# %%
odi_team=[]
for i in odi:
     odi_team.append(i.get_text().replace('\n',''))
odi_team[0:10]
# Out:
# ['England',
#  'India',
#  'New Zealand',
#  'Australia',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'West Indies',
#  'Afghanistan']

# %%
#lets extract all the tags
odi_match=soup1.find_all('td',class_='table-body__cell u-center-text')
odi_match[0:10]
# Out:
# [<td class="table-body__cell u-center-text">52</td>,
#  <td class="table-body__cell u-center-text">6,102</td>,
#  <td class="table-body__cell u-center-text">33</td>,
#  <td class="table-body__cell u-center-text">3,857</td>,
#  <td class="table-body__cell u-center-text">39</td>,
#  <td class="table-body__cell u-center-text">4,344</td>,
#  <td class="table-body__cell u-center-text">31</td>,
#  <td class="table-body__cell u-center-text">3,345</td>,
#  <td class="table-body__cell u-center-text">35</td>,
#  <td class="table-body__cell u-center-text">3,490</td>]

# %%
odi_matches=[]
for i in odi_match:
     odi_matches.append(i.get_text().replace('\n',''))
odi_matches[0:10]
# Out:
# ['52', '6,102', '33', '3,857', '39', '4,344', '31', '3,345', '35', '3,490']

# %%
odi_rating=soup1.find_all('td',class_='table-body__cell u-text-right rating')
odi_rating[0:10]
# Out:
# [<td class="table-body__cell u-text-right rating">117</td>,
#  <td class="table-body__cell u-text-right rating">117</td>,
#  <td class="table-body__cell u-text-right rating">111</td>,
#  <td class="table-body__cell u-text-right rating">108</td>,
#  <td class="table-body__cell u-text-right rating">100</td>,
#  <td class="table-body__cell u-text-right rating">90</td>,
#  <td class="table-body__cell u-text-right rating">80</td>,
#  <td class="table-body__cell u-text-right rating">78</td>,
#  <td class="table-body__cell u-text-right rating">59</td>,
#  <td class="table-body__cell u-text-right rating">45</td>]

# %%
odi_ratings=[]
for i in odi_rating:
     odi_ratings.append(i.get_text().replace('\n',''))
odi_ratings[0:10]
# Out:
# ['117', '117', '111', '108', '100', '90', '80', '78', '59', '45']

# %%
import pandas as pd
cricket=pd.DataFrame({})
cricket['odi']=odi_team[:10]
cricket['odi_match']=odi_matches[:10]
cricket['odi_rating']=odi_ratings[:10]

# %%
cricket
# Out:
#             odi odi_match odi_rating
# 0       England        52        117
# 1         India     6,102        117
# 2   New Zealand        33        111
# 3     Australia     3,857        108
# 4  South Africa        39        100
# 5      Pakistan     4,344         90
# 6    Bangladesh        31         80
# 7     Sri Lanka     3,345         78
# 8   West Indies        35         59
# 9   Afghanistan     3,490         45

# %% [markdown]
# # 5. Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
cricket1=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
cricket1
# Out:
# <Response [200]>

# %%
cricket1.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
soup3=BeautifulSoup(cricket1.content,'html.parser')
soup3
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
#lets extract all the tags 
odimen=soup3.find_all('td',class_='table-body__cell rankings-table__name name')
odimen[0:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/2759">Babar Azam</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/167">Aaron Finch</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/24">Francois du Plessis</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/170">David Warner</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/2751">Shai Hope</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
# ...

# %%
name=[]
for i in odimen:
     name.append(i.get_text().replace('\n',''))
name[0:10]
# Out:
# ['Rohit Sharma',
#  'Babar Azam',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope',
#  'Kane Williamson',
#  'Quinton de Kock',
#  'Jonny Bairstow']

# %%
men_cntry=soup3.find_all('span',class_='table-body__logo-text')
men_cntry[0:10]
# Out:
# [<span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>]

# %%
team=[]
for i in men_cntry:
     team.append(i.get_text().replace('\n',''))
team[0:10]
# Out:
# ['IND', 'PAK', 'NZ', 'AUS', 'SA', 'AUS', 'WI', 'NZ', 'SA', 'ENG']

# %%
men_rating=soup3.find_all('td',class_='table-body__cell rating')
men_rating[0:10]
# Out:
# [<td class="table-body__cell rating">842</td>,
#  <td class="table-body__cell rating">837</td>,
#  <td class="table-body__cell rating">818</td>,
#  <td class="table-body__cell rating">791</td>,
#  <td class="table-body__cell rating">790</td>,
#  <td class="table-body__cell rating">773</td>,
#  <td class="table-body__cell rating">773</td>,
#  <td class="table-body__cell rating">765</td>,
#  <td class="table-body__cell rating">755</td>,
#  <td class="table-body__cell rating">754</td>]

# %%
rating=[]
for i in men_rating:
     rating.append(i.get_text().replace('\n',''))
rating[0:10]
# Out:
# ['842', '837', '818', '791', '790', '773', '773', '765', '755', '754']

# %%
import pandas as pd
cricket1=pd.DataFrame({})
cricket1['odimen']=name[:10]
cricket1['men_cntry']=team[:10]
cricket1['men_rating']=rating[:10]

# %%
cricket1
# Out:
#                 odimen men_cntry men_rating
# 0         Rohit Sharma       IND        842
# 1           Babar Azam       PAK        837
# 2          Ross Taylor        NZ        818
# 3          Aaron Finch       AUS        791
# 4  Francois du Plessis        SA        790
# 5         David Warner       AUS        773
# 6            Shai Hope        WI        773
# 7      Kane Williamson        NZ        765
# 8      Quinton de Kock        SA        755
# 9       Jonny Bairstow       ENG        754

# %% [markdown]
# # 6. Top 10 ODI bowlers along with the records of their team and rating.

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
cricket2=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
cricket2
# Out:
# <Response [200]>

# %%
cricket2.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
soup4=BeautifulSoup(cricket2.content,'html.parser')
soup4
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
#lets extract all the tags 
bowlmen=soup4.find_all('td',class_='table-body__cell rankings-table__name name')
bowlmen[0:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/4572">Mujeeb Ur Rahman</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1124">Jasprit Bumrah</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1597">Mehedi Hasan</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/967">Chris Woakes</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1664">Kagiso Rabada</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/857">Josh Hazlewood</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1594">Mustafizur Rahman</a>
#  </td>,
# ...

# %%
bowler_name=[]
for i in bowlmen:
     bowler_name.append(i.get_text().replace('\n',''))
bowler_name[0:10]
# Out:
# ['Mujeeb Ur Rahman',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Chris Woakes',
#  'Kagiso Rabada',
#  'Josh Hazlewood',
#  'Mustafizur Rahman',
#  'Mohammad Amir',
#  'Pat Cummins',
#  'Matt Henry']

# %%
men_country=soup4.find_all('span',class_='table-body__logo-text')
men_country[0:10]
# Out:
# [<span class="table-body__logo-text">AFG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>]

# %%
country=[]
for i in men_country:
     country.append(i.get_text().replace('\n',''))
country[0:10]
# Out:
# ['AFG', 'IND', 'BAN', 'ENG', 'SA', 'AUS', 'BAN', 'PAK', 'AUS', 'NZ']

# %%
men_rating=soup4.find_all('td',class_='table-body__cell rating')
men_rating[0:10]
# Out:
# [<td class="table-body__cell rating">708</td>,
#  <td class="table-body__cell rating">700</td>,
#  <td class="table-body__cell rating">694</td>,
#  <td class="table-body__cell rating">675</td>,
#  <td class="table-body__cell rating">665</td>,
#  <td class="table-body__cell rating">660</td>,
#  <td class="table-body__cell rating">658</td>,
#  <td class="table-body__cell rating">647</td>,
#  <td class="table-body__cell rating">646</td>,
#  <td class="table-body__cell rating">641</td>]

# %%
bowl_rating=[]
for i in men_rating:
     bowl_rating.append(i.get_text().replace('\n',''))
bowl_rating[0:10]
# Out:
# ['708', '700', '694', '675', '665', '660', '658', '647', '646', '641']

# %%
import pandas as pd
cricket2=pd.DataFrame({})
cricket2['bowlmen']=bowler_name[:10]
cricket2['men_country']=country[:10]
cricket2['men_rating']=bowl_rating[:10]

# %%
cricket2
# Out:
#              bowlmen men_country men_rating
# 0   Mujeeb Ur Rahman         AFG        708
# 1     Jasprit Bumrah         IND        700
# 2       Mehedi Hasan         BAN        694
# 3       Chris Woakes         ENG        675
# 4      Kagiso Rabada          SA        665
# 5     Josh Hazlewood         AUS        660
# 6  Mustafizur Rahman         BAN        658
# 7      Mohammad Amir         PAK        647
# 8        Pat Cummins         AUS        646
# 9         Matt Henry          NZ        641

# %% [markdown]
# # 7. Top 10 ODI teams in women’s cricket along with the records for matches, points and rating

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
cricket3=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
cricket3
# Out:
# <Response [200]>

# %%
cricket3.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:image" content="https://w
# ...

# %%
soup5=BeautifulSoup(cricket3.content,'html.parser')
soup5
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
#lets extract all the tags 
women_odi=soup5.find_all('span',class_='u-hide-phablet')
women_odi[0:9]
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>]

# %%
women_team=[]
for i in women_odi:
     women_team.append(i.get_text().replace('\n',''))
women_team[0:9]
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka']

# %%
odi_women=soup5.find_all('td',class_='table-body__cell u-center-text')
odi_women[0:9]
# Out:
# [<td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,828</td>,
#  <td class="table-body__cell u-center-text">17</td>,
#  <td class="table-body__cell u-center-text">1,993</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,226</td>,
#  <td class="table-body__cell u-center-text">18</td>,
#  <td class="table-body__cell u-center-text">1,696</td>,
#  <td class="table-body__cell u-center-text">12</td>]

# %%
odi_womens=[]
for i in odi_women:
     odi_womens.append(i.get_text().replace('\n',''))
odi_womens[0:9]
# Out:
# ['24', '2,828', '17', '1,993', '20', '2,226', '18', '1,696', '12']

# %%
woodi_rating=soup5.find_all('td',class_='table-body__cell u-text-right rating')
woodi_rating[0:9]
# Out:
# [<td class="table-body__cell u-text-right rating">118</td>,
#  <td class="table-body__cell u-text-right rating">117</td>,
#  <td class="table-body__cell u-text-right rating">111</td>,
#  <td class="table-body__cell u-text-right rating">94</td>,
#  <td class="table-body__cell u-text-right rating">85</td>,
#  <td class="table-body__cell u-text-right rating">73</td>,
#  <td class="table-body__cell u-text-right rating">61</td>,
#  <td class="table-body__cell u-text-right rating">47</td>,
#  <td class="table-body__cell u-text-right rating">13</td>]

# %%
odiwomen_ratings=[]
for i in woodi_rating:
     odiwomen_ratings.append(i.get_text().replace('\n',''))
odiwomen_ratings[0:9]
# Out:
# ['118', '117', '111', '94', '85', '73', '61', '47', '13']

# %%
import pandas as pd
cricket3=pd.DataFrame({})
cricket3['women_odi']=women_team[:9]
cricket3['odi_women']=odi_womens[:9]
cricket3['woodi_rating']=odiwomen_ratings[:9]

# %%
cricket3
# Out:
#       women_odi odi_women woodi_rating
# 0     Australia        24          118
# 1  South Africa     2,828          117
# 2       England        17          111
# 3         India     1,993           94
# 4   New Zealand        20           85
# 5   West Indies     2,226           73
# 6      Pakistan        18           61
# 7    Bangladesh     1,696           47
# 8     Sri Lanka        12           13

# %% [markdown]
# # 8. Top 10 women’s ODI players along with the records of their team and rating.

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
cricket4=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
cricket4
# Out:
# <Response [200]>

# %%
cricket4.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
soup6=BeautifulSoup(cricket4.content,'html.parser')
soup6
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
#lets extract all the tags 
odiwomen=soup6.find_all('td',class_='table-body__cell rankings-table__name name')
odiwomen[0:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3176">Laura Wolvaardt</a>
#  </td>,
# ...

# %%
name=[]
for i in odiwomen:
     name.append(i.get_text().replace('\n',''))
name[0:10]
# Out:
# ['Tammy Beaumont',
#  'Meg Lanning',
#  'Stafanie Taylor',
#  'Alyssa Healy',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Laura Wolvaardt',
#  'Mithali Raj',
#  'Ellyse Perry',
#  'Natalie Sciver']

# %%
women_cntry=soup6.find_all('span',class_='table-body__logo-text')
women_cntry[0:10]
# Out:
# [<span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>]

# %%
team=[]
for i in women_cntry:
     team.append(i.get_text().replace('\n',''))
team[0:10]
# Out:
# ['ENG', 'AUS', 'WI', 'AUS', 'NZ', 'IND', 'SA', 'IND', 'AUS', 'ENG']

# %%
women_rating=soup6.find_all('td',class_='table-body__cell rating')
women_rating[0:10]
# Out:
# [<td class="table-body__cell rating">765</td>,
#  <td class="table-body__cell rating">749</td>,
#  <td class="table-body__cell rating">746</td>,
#  <td class="table-body__cell rating">741</td>,
#  <td class="table-body__cell rating">740</td>,
#  <td class="table-body__cell rating">719</td>,
#  <td class="table-body__cell rating">699</td>,
#  <td class="table-body__cell rating">693</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">685</td>]

# %%
rating=[]
for i in women_rating:
     rating.append(i.get_text().replace('\n',''))
rating[0:10]
# Out:
# ['765', '749', '746', '741', '740', '719', '699', '693', '691', '685']

# %%
import pandas as pd
cricket4=pd.DataFrame({})
cricket4['odiwomen']=name[:10]
cricket4['women_cntry']=team[:10]
cricket4['women_rating']=rating[:10]

# %%
cricket4
# Out:
#             odiwomen women_cntry women_rating
# 0     Tammy Beaumont         ENG          765
# 1        Meg Lanning         AUS          749
# 2    Stafanie Taylor          WI          746
# 3       Alyssa Healy         AUS          741
# 4  Amy Satterthwaite          NZ          740
# 5    Smriti Mandhana         IND          719
# 6    Laura Wolvaardt          SA          699
# 7        Mithali Raj         IND          693
# 8       Ellyse Perry         AUS          691
# 9     Natalie Sciver         ENG          685

# %% [markdown]
# # 9. Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
cricket5=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
cricket5
# Out:
# <Response [200]>

# %%
cricket5.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
soup7=BeautifulSoup(cricket5.content,'html.parser')
soup7
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
#lets extract all the tags 
allrounderwomen=soup7.find_all('td',class_='table-body__cell rankings-table__name name')
allrounderwomen[0:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/424">Marizanne Kapp</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3192">Deepti Sharma</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1800">Natalie Sciver</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/468">Jess Jonassen</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/478">Sophie Devine</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/430">Dane van Niekerk</a>
#  </td>,
# ...

# %%
name=[]
for i in allrounderwomen:
     name.append(i.get_text().replace('\n',''))
name[0:10]
# Out:
# ['Stafanie Taylor',
#  'Marizanne Kapp',
#  'Deepti Sharma',
#  'Natalie Sciver',
#  'Jess Jonassen',
#  'Sophie Devine',
#  'Dane van Niekerk',
#  'Katherine Brunt',
#  'Ashleigh Gardner',
#  'Shikha Pandey']

# %%
women_cntry=soup7.find_all('span',class_='table-body__logo-text')
women_cntry[0:10]
# Out:
# [<span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>]

# %%
team=[]
for i in women_cntry:
     team.append(i.get_text().replace('\n',''))
team[0:10]
# Out:
# ['WI', 'SA', 'IND', 'ENG', 'AUS', 'NZ', 'SA', 'ENG', 'AUS', 'IND']

# %%
women_rating=soup7.find_all('td',class_='table-body__cell rating')
women_rating[0:10]
# Out:
# [<td class="table-body__cell rating">410</td>,
#  <td class="table-body__cell rating">390</td>,
#  <td class="table-body__cell rating">357</td>,
#  <td class="table-body__cell rating">349</td>,
#  <td class="table-body__cell rating">301</td>,
#  <td class="table-body__cell rating">274</td>,
#  <td class="table-body__cell rating">252</td>,
#  <td class="table-body__cell rating">236</td>,
#  <td class="table-body__cell rating">223</td>,
#  <td class="table-body__cell rating">213</td>]

# %%
rating=[]
for i in women_rating:
     rating.append(i.get_text().replace('\n',''))
rating[0:10]
# Out:
# ['410', '390', '357', '349', '301', '274', '252', '236', '223', '213']

# %%
import pandas as pd
cricket5=pd.DataFrame({})
cricket5['allrounderwomen']=name[:10]
cricket5['women_cntry']=team[:10]
cricket5['women_rating']=rating[:10]

# %%
cricket5
# Out:
#     allrounderwomen women_cntry women_rating
# 0   Stafanie Taylor          WI          410
# 1    Marizanne Kapp          SA          390
# 2     Deepti Sharma         IND          357
# 3    Natalie Sciver         ENG          349
# 4     Jess Jonassen         AUS          301
# 5     Sophie Devine          NZ          274
# 6  Dane van Niekerk          SA          252
# 7   Katherine Brunt         ENG          236
# 8  Ashleigh Gardner         AUS          223
# 9     Shikha Pandey         IND          213

# %% [markdown]
# # 10. Python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in.

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests

# %%
mobile=requests.get('https://www.amazon.in/s?k=mobiles+under+20000&ref=nb_sb_noss_2')
mobile
# Out:
# <Response [200]>

# %%
mobile.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41DO8IyHTdL.css,31qGOnSAToL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11gKzVUTNZL.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,31q1y1irc5L.css,21j0IlW7xKL.css,01XPHJk60-L.css,014OeDQisGL.css,21aPhFy+riL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA
# ...

# %%
soup8=BeautifulSoup(mobile.content,'html.parser')
soup8
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:feature:aui-assets -->
# ...

# %%
#lets extract all the tags 
mobiles=soup8.find_all('span',class_='a-size-medium a-color-base a-text-normal')
mobiles[0:10]
# Out:
# [<span class="a-size-medium a-color-base a-text-normal" dir="auto">Redmi 9A (Nature Green, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera &amp; Full HD+ Display | Extra Upto INR 1000 Off on Exchange</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Redmi 9A (Nature Green, 3GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Oppo A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers</span>,
# ...

# %%
name=[]
for i in mobiles:
     name.append(i.get_text().replace('\n',''))
name[0:10]
# Out:
# ['Redmi 9A (Nature Green, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
#  'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display | Extra Upto INR 1000 Off on Exchange',
#  'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#  'Redmi 9A (Nature Green, 3GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
#  'Oppo A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi 9 Prime (Space Blue, 4GB RAM, 64GB Storage)- Full HD+ Display & AI Quad Camera',
#  'Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage)',
#  'Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
#  'Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers']

# %%
price=soup8.find_all('span',class_='a-price-whole')
price[0:10]
# Out:
# [<span class="a-price-whole">6,999</span>,
#  <span class="a-price-whole">8,799</span>,
#  <span class="a-price-whole">10,999</span>,
#  <span class="a-price-whole">16,499</span>,
#  <span class="a-price-whole">7,499</span>,
#  <span class="a-price-whole">11,990</span>,
#  <span class="a-price-whole">9,499</span>,
#  <span class="a-price-whole">18,499</span>,
#  <span class="a-price-whole">6,999</span>,
#  <span class="a-price-whole">6,199</span>]

# %%
prices=[]
for i in price:
     prices.append(i.get_text().replace('\n',''))
prices[0:10]
# Out:
# ['6,999',
#  '8,799',
#  '10,999',
#  '16,499',
#  '7,499',
#  '11,990',
#  '9,499',
#  '18,499',
#  '6,999',
#  '6,199']

# %%
rating=soup8.find_all('span',class_='a-size-base')
rating[0:10]
# Out:
# [<span class="a-size-base" dir="auto">19,634</span>,
#  <span class="a-size-base" dir="auto">16,318</span>,
#  <span class="a-size-base" dir="auto">33,331</span>,
# ...

# %%
ratings=[]
for i in rating:
     ratings.append(i.get_text().replace('\n',''))
ratings[0:10]
# Out:
# ['19,634',
#  '16,318',
#  '33,331',
#  'Selfies have always interested consumers and the development in camera technology has taken the craze to a new height. Apart from selfies, online meetings and video calls also require the quality of the front camera to be decent. The key factor defining the quality of a selfie picture or video calls are the pixels used in the front camera. Many smartphones launched in recent months offer up to 32MP front shooter or dual front camera as well. Here is a list of phones with a 32MP front camera under Rs 20,000.',
#  'If you are on the lookout for a smartphone with a 16-megapixel shooter on the front, here are your best options.',
#  'On a budget? Choose from these great smartphones that offer the best bang for your buck.',
# ...

# %% [markdown]
# # 11. Python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco.

# %%
weather=requests.get('https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YFbUu68zbIU')
weather
# Out:
# <Response [200]>

# %%
weather.content
# Out:
# b'<!DOCTYPE html>\n<html class="no-js">\n    <head>\n        <!-- Meta -->\n        <meta name="viewport" content="width=device-width">\n        <link rel="schema.DC" href="http://purl.org/dc/elements/1.1/" /><title>National Weather Service</title><meta name="DC.title" content="National Weather Service" /><meta name="DC.description" content="NOAA National Weather Service National Weather Service" /><meta name="DC.creator" content="US Department of Commerce, NOAA, National Weather Service" /><meta name="DC.date.created" scheme="ISO8601" content="" /><meta name="DC.language" scheme="DCTERMS.RFC1766" content="EN-US" /><meta name="DC.keywords" content="weather, National Weather Service" /><meta name="DC.publisher" content="NOAA\'s National Weather Service" /><meta name="DC.contributor" content="National Weather Service" /><meta name="DC.rights" content="http://www.weather.gov/disclaimer.php" /><meta name="rating" content="General" /><meta name="robots" content="index,follow" />\n\n      
# ...

# %%
soup3=BeautifulSoup(weather.content,'html.parser')
soup3
# Out:
# <!DOCTYPE html>
#
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# ...

# %%
#lets extract all the tags having job title
weather=soup3.find_all('p',class_="period-name")
weather[0:5]
# Out:
# [<p class="period-name">Tonight<br/><br/></p>,
#  <p class="period-name">Sunday<br/><br/></p>,
#  <p class="period-name">Sunday<br/>Night</p>,
#  <p class="period-name">Monday<br/><br/></p>,
#  <p class="period-name">Monday<br/>Night</p>]

# %%
days=[]
for i in weather:
     days.append(i.get_text().replace('\n',''))
days[0:5]
# Out:
# ['Tonight', 'Sunday', 'SundayNight', 'Monday', 'MondayNight']

# %%
temp=soup3.find_all('p',class_="temp temp-low")
temp[0:5]
# Out:
# [<p class="temp temp-low">Low: 42 °F</p>,
#  <p class="temp temp-low">Low: 46 °F</p>,
#  <p class="temp temp-low">Low: 47 °F</p>,
#  <p class="temp temp-low">Low: 49 °F</p>,
#  <p class="temp temp-low">Low: 49 °F</p>]

# %%
days_temp=[]
for i in temp:
     days_temp.append(i.get_text().replace('\n',''))
days_temp[0:5]
# Out:
# ['Low: 42 °F', 'Low: 46 °F', 'Low: 47 °F', 'Low: 49 °F', 'Low: 49 °F']

# %%
weat=soup3.find_all('p',class_="short-desc")
weat[0:5]
# Out:
# [<p class="short-desc">Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>]

# %%
days_weat=[]
for i in weat:
     days_weat.append(i.get_text().replace('\n',''))
days_weat[0:5]
# Out:
# ['Clear', 'Sunny', 'Mostly Clear', 'Sunny', 'Mostly Clear']

# %%
import pandas as pd
weather=pd.DataFrame({})
weather['weather']=days[:5]
weather['temp']=days_temp[:5]
weather['weat']=days_weat[:5]

# %%
weather
# Out:
#        weather        temp          weat
# 0      Tonight  Low: 42 °F         Clear
# 1       Sunday  Low: 46 °F         Sunny
# 2  SundayNight  Low: 47 °F  Mostly Clear
# 3       Monday  Low: 49 °F         Sunny
# 4  MondayNight  Low: 49 °F  Mostly Clear
